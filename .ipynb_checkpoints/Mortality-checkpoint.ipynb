# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Retrieve mortality data from https://www.mortality.org

# %%
d = pd.read_csv('https://www.mortality.org/Public/STMF/Outputs/stmf.csv', header = 1, dtype = {'CountryCode' : "str", 'Year': int, 'Week' : int, \
     'Sex': "str", 'D0_14': float, 'D15_64': float, 'D65_74': float, 'D75_84': float, 'D85p': float,  \
     'DTotal': float, 'R0_14': float, 'R15_64': float, 'R65_74': float, 'R75_84': float, 'R85p': float,  \
     'RTotal': float, 'Split': int,   'SplitSex': int, 'Forecast': int })

# %% [markdown]
# Filter for USA

# %%
USA_data_both = d[ (d['CountryCode']=='USA') & (d['Sex']=='b') ]

# %% [markdown]
# Plot mortality of all (US-) people

# %%
fig, ax = plt.subplots(figsize=(12,8))
for i in range(2011,2021):
    USA_data_both[USA_data_both['Year'] == i].plot( x='Week', y='RTotal', label=str(i),ax = ax);

# %% [markdown]
# Just people over 85:

# %%
fig, ax = plt.subplots(figsize=(12,8))
for i in range(2011,2021):
    USA_data_both[USA_data_both['Year'] == i].plot( x='Week', y='R85p', label=str(i),ax = ax);
